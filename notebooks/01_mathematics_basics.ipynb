# %% [markdown]
# # Mathematics Basics for Deep Learning
#
# This notebook covers fundamental mathematical concepts needed for deep learning.

# %%
import sys
sys.path.append('../')

from src.mathematics import linear_algebra, calculus, statistics
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Linear Algebra

# %%
# Vector operations
linear_algebra.vector_operations_example()
# Out:
# Vector addition: [1 2 3] + [4 5 6] = [5 7 9]
# Scalar multiplication: 2 * [1 2 3] = [2 4 6]
# Dot product: [1 2 3] · [4 5 6] = 32
# Cross product: [1 2 3] × [4 5 6] = [-3  6 -3]
# (array([1, 2, 3]), array([4, 5, 6]), array([5, 7, 9]), np.int64(32))

# %%
# Matrix operations
linear_algebra.matrix_operations_example()
# Out:
# Matrix addition:
# [[1 2]
#  [3 4]]
# +
# [[5 6]
#  [7 8]]
# =
# [[ 6  8]
#  [10 12]]
#
# Matrix multiplication:
# [[1 2]
#  [3 4]]
# ×
# [[5 6]
#  [7 8]]
# =
# [[19 22]
#  [43 50]]
#
# Matrix transpose:
# [[1 2]
#  [3 4]]
# ^T
# =
# [[1 3]
#  [2 4]]
#
# Determinant of A: -2.0000000000000004
# Inverse of A:
# [[-2.   1. ]
#  [ 1.5 -0.5]]
# (array([[1, 2],
#         [3, 4]]),
#  array([[5, 6],
#         [7, 8]]),
#  array([[19, 22],
#         [43, 50]]),
#  np.float64(-2.0000000000000004))

# %% [markdown]
# ## Calculus

# %%
# Gradient descent
calculus.gradient_descent_example()
# Out:
# Starting point: 5.0
# Final point: -0.9999143651384377
# Minimum value: 7.3333294992039555e-09
# True minimum at x = -1, f(-1) = 0
# ([5.0,
#   3.8,
#   2.84,
#   2.072,
#   1.4576,
#   0.9660799999999999,
#   0.5728639999999999,
#   0.2582911999999999,
#   0.00663295999999991,
#   -0.1946936320000001,
#   -0.3557549056000001,
#   -0.4846039244800001,
#   -0.5876831395840001,
#   -0.6701465116672001,
#   -0.73611720933376,
#   -0.788893767467008,
#   -0.8311150139736064,
#   -0.8648920111788851,
#   -0.8919136089431081,
#   -0.9135308871544865,
#   -0.9308247097235892,
#   -0.9446597677788714,
#   -0.9557278142230972,
#   -0.9645822513784778,
#   -0.9716658011027822,
#   -0.9773326408822258,
#   -0.9818661127057806,
#   -0.9854928901646245,
#   -0.9883943121316996,
#   -0.9907154497053596,
#   -0.9925723597642877,
#   -0.9940578878114301,
#   -0.9952463102491441,
#   -0.9961970481993153,
#   -0.9969576385594523,
#   -0.9975661108475619,
#   -0.9980528886780495,
#   -0.9984423109424396,
#   -0.9987538487539517,
#   -0.9990030790031613,
#   -0.999202463202529,
#   -0.9993619705620232,
#   -0.9994895764496186,
#   -0.9995916611596949,
#   -0.999673328927756,
#   -0.9997386631422047,
#   -0.9997909305137638,
#   -0.999832744411011,
#   -0.9998661955288088,
#   -0.9998929564230471,
#   -0.9999143651384377],
#  [36.0,
#   23.04,
#   14.7456,
#   9.437184,
#   6.03979776,
#   3.8654705664,
#   2.473901162496,
#   1.5832967439974397,
#   1.0133099161583614,
#   0.6485183463413513,
#   0.4150517416584647,
#   0.2656331146614175,
#   0.1700051933833071,
#   0.10880332376531654,
#   0.06963412720980267,
#   0.044565841414273666,
#   0.028522138505135186,
#   0.01825416864328655,
#   0.011682667931703361,
#   0.007476907476290151,
#   0.004785220784825683,
#   0.0030625413022884462,
#   0.001960026433464601,
#   0.0012544169174173447,
#   0.0008028268271470518,
#   0.0005138091693741575,
#   0.0003288378683994342,
#   0.00021045623577564676,
#   0.00013469199089644057,
#   8.620287417371308e-05,
#   5.5169839471180815e-05,
#   3.530869726153796e-05,
#   2.2597566247339884e-05,
#   1.4462442398333053e-05,
#   9.255963134946477e-06,
#   5.923816406405713e-06,
#   3.7912425000508065e-06,
#   2.4263952000946887e-06,
#   1.5528929280250736e-06,
#   9.93851473896079e-07,
#   6.360649432712862e-07,
#   4.0708156368030046e-07,
#   2.605322008131239e-07,
#   1.6674060854260375e-07,
#   1.0671398942285748e-07,
#   6.829695320398343e-08,
#   4.3710050023904046e-08,
#   2.797443199309413e-08,
#   1.7903636462257566e-08,
#   1.1458327398017332e-08,
#   7.3333294992039555e-09])

# %% [markdown]
# ## Statistics

# %%
# Descriptive statistics
statistics.descriptive_statistics_example()
# Out:
# Descriptive Statistics:
#   Mean: 100.29
#   Median: 100.38
#   Standard Deviation: 14.68
#   Variance: 215.53
#   Min: 51.38
#   Max: 157.79
#   25th Percentile: 90.29
#   75th Percentile: 109.72
#   IQR: 19.43
# {'mean': np.float64(100.28998083733488),
#  'median': np.float64(100.37950918352333),
#  'std': np.float64(14.680893116210314),
#  'variance': np.float64(215.52862268959137),
#  'min': np.float64(51.38098989896391),
#  'max': np.float64(157.7909723598208)}
