# %% [markdown]
# # Neural Networks Fundamentals
#
# This notebook covers the basics of neural networks.

# %%
import sys
sys.path.append('../')

from src.deep_learning import neural_networks
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## XOR Problem

# %%
# Solve XOR problem with neural network
neural_networks.xor_problem_example()

# %% [markdown]
# ## Linear Regression

# %%
# Neural network for regression
neural_networks.linear_regression_example()
